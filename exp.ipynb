# %%
a = 3
print(a)
# Out:
# 3

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\software\\thesis_project\\transformers-explainability\\transformers-explainability'

# %%
with open("legal_datasets/esempio.txt", "w") as f:
    f.write("Ciao mondo!\n")
    f.write("Questa è la seconda riga.\n")
